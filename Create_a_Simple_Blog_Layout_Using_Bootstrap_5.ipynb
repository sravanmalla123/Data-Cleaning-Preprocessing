# %% [markdown]
# <a href="https://colab.research.google.com/github/sravanmalla123/Data-Cleaning-Preprocessing/blob/main/Create_a_Simple_Blog_Layout_Using_Bootstrap_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ```html
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Simple Blog Layout</title>
#     <!-- Bootstrap CSS -->
#     <link href="https://cdn.jsdelivr.net/npm/bootstrap@5.3.0/dist/css/bootstrap.min.css" rel="stylesheet">
#     <style>
#         body {
#             display: flex;
#             flex-direction: column;
#             min-height: 100vh;
#         }
#         .navbar {
#             margin-bottom: 20px;
#         }
#         .footer {
#             margin-top: auto;
#             padding: 20px 0;
#             background-color: #f8f9fa;
#             border-top: 1px solid #e9ecef;
#         }
#         .card {
#             margin-bottom: 20px;
#         }
#     </style>
# </head>
# <body>
#     <!-- Navbar -->
#     <nav class="navbar navbar-expand-lg navbar-light bg-light">
#         <div class="container">
#             <a class="navbar-brand" href="#">My Blog</a>
#             <button class="navbar-toggler" type="button" data-bs-toggle="collapse" data-bs-target="#navbarNav" aria-controls="navbarNav" aria-expanded="false" aria-label="Toggle navigation">
#                 <span class="navbar-toggler-icon"></span>
#             </button>
#             <div class="collapse navbar-collapse" id="navbarNav">
#                 <ul class="navbar-nav ms-auto">
#                     <li class="nav-item">
#                         <a class="nav-link active" aria-current="page" href="#">Home</a>
#                     </li>
#                     <li class="nav-item">
#                         <a class="nav-link" href="#">About</a>
#                     </li>
#                     <li class="nav-item">
#                         <a class="nav-link" href="#">Contact</a>
#                     </li>
#                 </ul>
#             </div>
#         </div>
#     </nav>
#
#     <!-- Main Content - Blog Posts -->
#     <div class="container">
#         <div class="row">
#             <div class="col-lg-8">
#                 <h1 class="mb-4">Latest Posts</h1>
#
#                 <!-- Blog Post 1 -->
#                 <div class="card">
#                     <img src="https://via.placeholder.com/700x350" class="card-img-top" alt="...">
#                     <div class="card-body">
#                         <h5 class="card-title">Blog Post Title 1</h5>
#                         <p class="card-text">This is a brief summary of the first blog post. It gives the reader an idea of what the post is about before clicking to read more.</p>
#                         <a href="#" class="btn btn-primary">Read More</a>
#                     </div>
#                     <div class="card-footer text-muted">
#                         Posted on January 1, 2023 by <a href="#">Blogger Name</a>
#                     </div>
#                 </div>
#
#                 <!-- Blog Post 2 -->
#                 <div class="card">
#                     <img src="https://via.placeholder.com/700x350" class="card-img-top" alt="...">
#                     <div class="card-body">
#                         <h5 class="card-title">Blog Post Title 2</h5>
#                         <p class="card-text">Here's another great blog post. This one delves into interesting topics and offers valuable insights.</p>
#                         <a href="#" class="btn btn-primary">Read More</a>
#                     </div>
#                     <div class="card-footer text-muted">
#                         Posted on January 15, 2023 by <a href="#">Blogger Name</a>
#                     </div>
#                 </div>
#
#                 <!-- Blog Post 3 -->
#                 <div class="card">
#                     <img src="https://via.placeholder.com/700x350" class="card-img-top" alt="...">
#                     <div class="card-body">
#                         <h5 class="card-title">Blog Post Title 3</h5>
#                         <p class="card-text">The third blog post provides an in-depth look at a trending subject. Don't miss out on this informative read!</p>
#                         <a href="#" class="btn btn-primary">Read More</a>
#                     </div>
#                     <div class="card-footer text-muted">
#                         Posted on February 1, 2023 by <a href="#">Blogger Name</a>
#                     </div>
#                 </div>
#             </div>
#
#             <!-- Sidebar -->
#             <div class="col-lg-4">
#                 <div class="card mb-4">
#                     <div class="card-header">About</div>
#                     <div class="card-body">
#                         <p>Welcome to my simple blog! Here you'll find articles on various topics.</p>
#                         <a href="#" class="btn btn-secondary">Learn More</a>
#                     </div>
#                 </div>
#
#                 <div class="card mb-4">
#                     <div class="card-header">Categories</div>
#                     <div class="card-body">
#                         <ul class="list-unstyled mb-0">
#                             <li><a href="#">Web Development</a></li>
#                             <li><a href="#">Design</a></li>
#                             <li><a href="#">Programming</a></li>
#                             <li><a href="#">Tutorials</a></li>
#                         </ul>
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </div>
#
#     <!-- Footer -->
#     <footer class="footer mt-auto py-3 bg-light">
#         <div class="container text-center">
#             <span class="text-muted">Copyright &copy; 2023 My Blog. All Rights Reserved.</span>
#         </div>
#     </footer>
#
#     <!-- Bootstrap Bundle with Popper -->
#     <script src="https://cdn.jsdelivr.net/npm/bootstrap@5.3.0/dist/js/bootstrap.bundle.min.js"></script>
# </body>
# </html>
# ```
